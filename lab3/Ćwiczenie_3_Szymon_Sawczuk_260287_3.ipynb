# %% [markdown]
# <h1>Sieci neuronowe - ćwiczenie 3</h1>

# %%
# !pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in /Users/szymon/.pyenv/versions/3.10.6/lib/python3.10/site-packages (0.0.2)
#
# [notice] A new release of pip available: 22.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.metrics as metrics

# %% [markdown]
# <h3>Przygotowanie danych na podstawie poprzedniego ćwiczenia</h3>

# %%
# original code from https://archive.ics.uci.edu/dataset/45/heart+disease
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 
  
# data (as pandas dataframes) 
heart_data = heart_disease.data.original

# %%
df: pd.DataFrame = heart_data

# repearing of the inbalnace in classification and removing null values
df["num"] = df["num"].replace([2, 3, 4], 1) #change classes to binary classification
print(df["num"].value_counts())

#get null values of ca and remove them
null_idx = df[df["ca"].isnull()].index 
print(null_idx)
df = df.drop(null_idx)
df = df.reset_index(drop=True) 
print(df["num"].value_counts())

#get null values of thel and remove them
null_idx = df[df["thal"].isnull()].index 
print(null_idx)
df = df.drop(null_idx)
df = df.reset_index(drop=True) 
print(df["num"].value_counts())

# balance classes to same amount 138
random_idx = df.query("num == 0").sample(df["num"].value_counts()[0] - df["num"].value_counts()[1]).index 
df = df.drop(random_idx)
df = df.reset_index(drop=True)
print(df["num"].value_counts())

df_without_num = df.loc[:, df.columns != "num"]
std_features = (df_without_num - df_without_num.mean() )/ df_without_num.std() #(value-mean)/variance

result_df = std_features
result_df["heart_disease"] = df["num"]

# data not standarized 4. Danych znormalizowanych i nieznormalizowanych
n_std_result = df_without_num
n_std_result["heart_disease"] = df["num"]

result_df
# Out:
# num
# 0    164
# 1    139
# Name: count, dtype: int64
# Index([166, 192, 287, 302], dtype='int64')
# num
# 0    161
# 1    138
# Name: count, dtype: int64
# Index([87, 264], dtype='int64')
# num
# 0    160
# 1    137
# Name: count, dtype: int64
# num
# 0    137
# 1    137
# Name: count, dtype: int64
#           age       sex        cp  trestbps      chol       fbs   restecg  \
# 0    0.902861  0.692333 -2.304406  0.756513 -0.289939  2.487541  0.990968
# 1    1.344223  0.692333  0.863189  1.599362  0.726107 -0.400536  0.990968
# 2    1.344223  0.692333  0.863189 -0.648235 -0.366622 -0.400536  0.990968
# 3   -1.965997  0.692333 -0.192676 -0.086336  0.035962 -0.400536 -1.020330
# 4   -1.524634 -1.439120 -1.248541 -0.086336 -0.845888 -0.400536  0.990968
# ..        ...       ...       ...       ...       ...       ...       ...
# 269  0.240817 -1.439120  0.863189  0.475563 -0.136574 -0.400536 -1.020330
# 270 -1.083272  0.692333 -2.304406 -1.210134  0.304352 -0.400536 -1.020330
# 271  1.454564  0.692333  0.863189  0.700323 -1.056766  2.487541 -1.020330
# 272  0.240817  0.692333  0.863189 -0.086336 -2.245347 -0.400536 -1.020330
# 273  0.240817 -1.439120 -1.248541 -0.086336 -0.232427 -0.400536  0.990968
#
#       thalach     exang   oldpeak     slope        ca      thal  heart_disease
# 0    0.053532 -0.698101  1.025712  2.226227 -0.749286  0.634142              0
# 1   -1.790911  1.427229  0.351136  0.608227  2.377177 -0.908061              1
# 2   -0.868690  1.427229  1.278677  0.608227  1.335023  1.148210              1
# 3    1.678398 -0.698101  2.037575  2.226227 -0.749286 -0.908061              0
# 4    1.019668 -0.698101  0.266814 -1.009774 -0.749286 -0.908061              0
# ..        ...       ...       ...       ...       ...       ...            ...
# 269 -1.132181  1.427229 -0.745049  0.608227 -0.749286  1.148210              1
# 270 -0.736944 -0.698101  0.098170  0.608227 -0.749286  1.148210              1
# 271 -0.341706 -0.698101  1.953253  0.608227  1.335023  1.148210              1
# 272 -1.483504  1.427229  0.098170  0.608227  0.292868  1.148210              1
# 273  1.107499 -0.698101 -0.913693  0.608227  0.292868 -0.908061              1
#
# [274 rows x 14 columns]

# %%
def train_test_split(features, targets, percentage):
    choices = np.random.choice(range(features.shape[0]), size=(int(features.shape[0] * percentage/100),), replace=False) 
    split = np.zeros(features.shape[0], dtype=bool)
    split[choices] = True

    return features[split], targets[split], features[~split], targets[~split]

# %%
features = result_df.loc[:, result_df.columns != "heart_disease"].to_numpy()
targets = result_df["heart_disease"].to_numpy()

x_train, y_train, x_test, y_test = train_test_split(features, targets, 70)

# %% [markdown]
# <h1>Przygotowanie modelu</h1>

# %%
def sigmoid(n):
    return 1 / (1 + np.exp(-n))


def sigmoid_der(n):
    return sigmoid(n) * (1 - sigmoid(n))

# %%
class Neuron:
    weights: np.ndarray
    bias: float
    _err: np.ndarray 

    def init_params(self, std_dev: float, weights_size: float):
        self.weights = np.random.normal(scale=std_dev, size=weights_size) # initialize weights 
        self.bias = np.random.normal(scale=std_dev) #initialize bias 

    def forward(self, x: np.ndarray) -> np.ndarray: 
        return sigmoid(np.dot(x, self.weights) + self.bias)
        
    def backward(self, x: np.ndarray, err: np.ndarray, is_output: bool, curr_weights: np.ndarray = np.array([])) -> np.ndarray:
        if not is_output:
            err = err.T @ curr_weights
        self._err = err * sigmoid_der(np.dot(x, self.weights) + self.bias)
        return self._err

    def update(self, learning_rate: float, x: np.ndarray) -> None:
        self.weights = self.weights - learning_rate * np.dot(x.T, self._err)
        self.bias = self.bias - learning_rate * np.sum(self._err)

class Layer:
    _cache_x: np.ndarray
    neurons: list[Neuron]

    def __init__(self, neurons_amount: int):
        self.neurons = []
        for _ in range(neurons_amount):
            self.neurons.append(Neuron())

    def init_params(self, std_dev: float, weights_size: float) -> None:
        for neuron in self.neurons:
            neuron.init_params(std_dev, weights_size)

    def forward(self, x: np.ndarray) -> np.ndarray:
        self._cache_x = x
        return np.array([neuron.forward(x) for neuron in self.neurons]).T
    
    def backward(self, err: np.ndarray, is_output: bool, curr_weights: np.ndarray = np.array([])) -> np.ndarray:
        return np.array([neuron.backward(self._cache_x, err, is_output, curr_weights[neuron_index] if not is_output else None) for neuron_index, neuron in enumerate(self.neurons)])

    def get_weights(self) -> np.ndarray:
        return np.array([neuron.weights for neuron in self.neurons]).T
    
    def update(self, learning_rate: float):
        for neuron in self.neurons:
            neuron.update(learning_rate, self._cache_x)

class MultilayerNetwork:
    _layers : list[Layer]
    _batch_size: int

    def __init__(self, hidden_layers_sizes: tuple):
        self._layers = []
        for layer_size in hidden_layers_sizes:
            self._layers.append(Layer(layer_size))

        # output layer
        self._layers.append(Layer(1))

    def __cross_entropy_loss(self, y, y_pred):
        return np.sum(-y * np.log(y_pred) - (1 - y) * np.log(1 - y_pred), axis=1)

    def __cross_entropy_loss_der(self, y, y_pred):
        return np.sum((1 - y) / (1 - y_pred) - y / y_pred, axis=1)

    def forward(self, x: np.ndarray) -> np.ndarray:
        for layer in self._layers:
            x = layer.forward(x)
        return x   
    
    def backward(self, y_train: np.ndarray, y_pred: np.ndarray):
        err = self._layers[-1].backward(self.__cross_entropy_loss_der(y_train, y_pred), True) # calculate error on output layer
        curr_weights = self._layers[-1].get_weights()

        for layer in reversed(self._layers[:-1]):
            err = layer.backward(err, False, curr_weights)
            curr_weights = layer.get_weights()

    def predict(self, x: np.ndarray) -> np.ndarray:
        y_pred = self.forward(x)

        y_pred[y_pred >= 0.5] = 1
        y_pred[y_pred < 0.5] = 0

        return y_pred

    def optimize(self, x_train: np.ndarray, y_train: np.ndarray, x_test: np.ndarray, y_test: np.ndarray, batch_size: int, learning_rate: float, 
                        max_iter: int, std_dev: float, verb = False) -> (list, list, list, list, list):
        self._batch_size = batch_size
        
        # init helper lists
        losses = [] 
        losses_test = []

        accuracy = []
        f_score = []
        recalls = []

        # init weights and biases
        curr_size = x_train.shape[1]

        for layer in self._layers:
            layer.init_params(std_dev, curr_size)
            curr_size = len(layer.neurons)

        #fix shape of y data to match further calculations
        if len(y_test.shape) == 1:
            y_test = y_test[np.newaxis].T 

        if len(y_train.shape) == 1:
            y_train = y_train[np.newaxis].T

        # check if batch_size is not larger than size of training data
        if batch_size > x_train.shape[0]:
            batch_size = x_train.shape[0]

        for index in range(max_iter): #learn for max_iter     
            # shuffle training data
            shuffle = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[shuffle]
            y_train_shuffled = y_train[shuffle]
            
            # for each batch perform learning
            for batch_start_index in range(0, x_train.shape[0], batch_size):
                x_train_batch = x_train_shuffled[batch_start_index:batch_start_index+batch_size] 
                y_train_batch = y_train_shuffled[batch_start_index:batch_start_index+batch_size] 

                y_pred = self.forward(x_train_batch)
                self.backward(y_train_batch, y_pred)
                
                for layer in self._layers:
                    layer.update(learning_rate)

                new_train_batch_loss = np.array([])
                new_train_batch_loss = np.append(new_train_batch_loss, self.__cross_entropy_loss(y_train_batch, y_pred))

            new_train_loss = np.mean(new_train_batch_loss)

            test_pred = self.forward(x_test)
            new_test_loss = np.mean(self.__cross_entropy_loss(y_test, test_pred))

            #append to helper lists
            losses.append(new_train_loss)
            losses_test.append(new_test_loss)

            # predict test values as 0 or 1
            test_pred = self.predict(x_test)

            #calculate scores for each iteration
            accuracy.append(metrics.accuracy_score(y_test, test_pred))
            f_score.append(metrics.f1_score(y_test, test_pred))
            recalls.append(metrics.recall_score(y_test, test_pred))

            if verb and index % 100 == 0: 
                print("---------------------------------------------- Interation " + str(index))
                print("Train loss on " + str(index) + " iteration: ", losses[index])
                print("Test loss on " + str(index) + " iteration: ", losses_test[index])
                print("Accuracy on " + str(index) + " iteration: ", accuracy[index])
                print("Recall on " + str(index) + " iteration: ", recalls[index])
                print("Fscore on " + str(index) + " iteration: ", f_score[index])
                print("----------------------------------------------\n")

        print("Result of learning process for " + str(max_iter) + " iterations")
        print("--------------------------------------------------------\n")
        print("Train loss: ", losses[-1])
        print("Test loss: ", losses_test[-1])
        print("----------------------------------------------\n")
        print("Scores")
        print("Accuracy: ", accuracy[-1])
        print("F_score: ", f_score[-1])
        print("Recall: ", recalls[-1])
        return losses, losses_test, accuracy, f_score, recalls  

    def plot_learning(self, losses: list, losses_test: list, title: str, axs = None):
        if axs == None:
            plt.plot(np.arange(len(losses)), losses, label="Train Loss")
            plt.plot(np.arange(len(losses)), losses_test, label="Test loss")
            plt.plot(np.convolve(losses, np.ones(self._batch_size)/self._batch_size, mode='valid'), label="Train loss smooth") #rolling avarage to smooth line
            plt.title(title)
            plt.legend()
            plt.show()
        else:
            axs.plot(np.arange(len(losses)), losses, label="Train Loss")
            axs.plot(np.arange(len(losses)), losses_test, label="Test loss")
            axs.plot(np.convolve(losses, np.ones(self._batch_size)/self._batch_size, mode='valid'), label="Train loss smooth") #rolling avarage to smooth line
            axs.set_title(title)
            axs.legend()

# %%
#1. Różna wymiarowość warstwy ukrytej
hidden1 = (4, 3)
hidden2 = (20, 10)
hidden3 = (100, 50)

#2. Różne wartości współczynnika uczenia
learning1 = 0.001
learning2 = 0.01

#3. Różne odchylenia standardowych przy inicjalizacji wag
std_dev1 = 0.8
std_dev2 = 0.3

#5. Różne liczby warstw
hidden4 = (20,)
hidden5 = (20, 20)
hidden6 = (20, 20, 20)

max_iter = 500

options_title = ["hidden_layer " + str(hidden1), "hidden_layer " + str(hidden2), "hidden_layer " + str(hidden3),
           "learning " + str(learning1), "learning " + str(learning2),
           "std_dev " + str(std_dev1), "std_dev " + str(std_dev2),
           "layer size " + str(hidden4), "layer size " + str(hidden5), "layer size " + str(hidden6),
           "stadarized data", "not standarized data"]

options = [[hidden1, learning1, std_dev2], [hidden2, learning1, std_dev2], [hidden3, learning1, std_dev2],
           [hidden2, learning1, std_dev2], [hidden2, learning2, std_dev2],
           [hidden2, learning1, std_dev1], [hidden2, learning1, std_dev2],
           [hidden4, learning1, std_dev2], [hidden5, learning1, std_dev2], [hidden6, learning1, std_dev2]]

# %%
hidden_layers = [hidden1, hidden2, hidden3]
results = []
models = []
for index_option, option in enumerate(options):
    print("\n" + options_title[index_option])
    model = MultilayerNetwork(option[0])
    result = model.optimize(x_train, y_train, x_test, y_test, 30, option[1], max_iter, option[2], verb=True)
    models.append(model)
    results.append(result)
# Out:
# hidden_layer (4, 3)
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.6767316759163126
# Test loss on 0 iteration:  0.6989387209582046
# Accuracy on 0 iteration:  0.4578313253012048
# Recall on 0 iteration:  0.0
# Fscore on 0 iteration:  0.0
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.7064126141916703
# Test loss on 100 iteration:  0.6927986303331408
# Accuracy on 100 iteration:  0.4578313253012048
# Recall on 100 iteration:  0.0
# Fscore on 100 iteration:  0.0
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.6960875129978022
# Test loss on 200 iteration:  0.6848275115871053
# Accuracy on 200 iteration:  0.4939759036144578
# Recall on 200 iteration:  0.08888888888888889
# Fscore on 200 iteration:  0.15999999999999998
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.6290810490692886
# Test loss on 300 iteration:  0.6529153421542979
# Accuracy on 300 iteration:  0.7349397590361446
# Recall on 300 iteration:  0.5555555555555556
# Fscore on 300 iteration:  0.6944444444444444
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.5493487018772315
# Test loss on 400 iteration:  0.5586452141741158
# Accuracy on 400 iteration:  0.8433734939759037
# Recall on 400 iteration:  0.7777777777777778
# Fscore on 400 iteration:  0.8433734939759038
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.3526735832336297
# Test loss:  0.45281640785349964
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8554216867469879
# F_score:  0.8604651162790697
# Recall:  0.8222222222222222
#
# hidden_layer (20, 10)
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.7433384743912602
# Test loss on 0 iteration:  0.6945569395298171
# Accuracy on 0 iteration:  0.5421686746987951
# Recall on 0 iteration:  1.0
# Fscore on 0 iteration:  0.7031249999999999
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.6331234261329896
# Test loss on 100 iteration:  0.6566599790337345
# Accuracy on 100 iteration:  0.7590361445783133
# Recall on 100 iteration:  0.6
# Fscore on 100 iteration:  0.7297297297297297
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.35130646573176766
# Test loss on 200 iteration:  0.4944997406186973
# Accuracy on 200 iteration:  0.8554216867469879
# Recall on 200 iteration:  0.8444444444444444
# Fscore on 200 iteration:  0.8636363636363636
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.1177105285366322
# Test loss on 300 iteration:  0.3958999095471657
# Accuracy on 300 iteration:  0.8674698795180723
# Recall on 300 iteration:  0.8666666666666667
# Fscore on 300 iteration:  0.8764044943820225
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.6295228354167571
# Test loss on 400 iteration:  0.38418132906467656
# Accuracy on 400 iteration:  0.8313253012048193
# Recall on 400 iteration:  0.8666666666666667
# Fscore on 400 iteration:  0.8478260869565217
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.6628896114281543
# Test loss:  0.3844697928407683
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8072289156626506
# F_score:  0.8297872340425533
# Recall:  0.8666666666666667
#
# hidden_layer (100, 50)
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.6015844696514148
# Test loss on 0 iteration:  0.7057128763519592
# Accuracy on 0 iteration:  0.46987951807228917
# Recall on 0 iteration:  0.08888888888888889
# Fscore on 0 iteration:  0.15384615384615385
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.43176015111118066
# Test loss on 100 iteration:  0.3835501523931788
# Accuracy on 100 iteration:  0.8795180722891566
# Recall on 100 iteration:  0.8666666666666667
# Fscore on 100 iteration:  0.8863636363636364
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.274534435117219
# Test loss on 200 iteration:  0.36736214040891046
# Accuracy on 200 iteration:  0.8674698795180723
# Recall on 200 iteration:  0.8666666666666667
# Fscore on 200 iteration:  0.8764044943820225
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.1519921125149405
# Test loss on 300 iteration:  0.3642457106908132
# Accuracy on 300 iteration:  0.8674698795180723
# Recall on 300 iteration:  0.8666666666666667
# Fscore on 300 iteration:  0.8764044943820225
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.2954329736237799
# Test loss on 400 iteration:  0.36379830207401626
# Accuracy on 400 iteration:  0.8674698795180723
# Recall on 400 iteration:  0.8888888888888888
# Fscore on 400 iteration:  0.8791208791208792
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.13805651681804568
# Test loss:  0.36481190729843327
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8554216867469879
# F_score:  0.8695652173913044
# Recall:  0.8888888888888888
#
# learning 0.001
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.6796751660000057
# Test loss on 0 iteration:  0.68385684522399
# Accuracy on 0 iteration:  0.5903614457831325
# Recall on 0 iteration:  0.9333333333333333
# Fscore on 0 iteration:  0.7118644067796611
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.585491224634453
# Test loss on 100 iteration:  0.5745034839692096
# Accuracy on 100 iteration:  0.8192771084337349
# Recall on 100 iteration:  0.7777777777777778
# Fscore on 100 iteration:  0.823529411764706
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.5393960692182442
# Test loss on 200 iteration:  0.42887437626556957
# Accuracy on 200 iteration:  0.8554216867469879
# Recall on 200 iteration:  0.8222222222222222
# Fscore on 200 iteration:  0.8604651162790697
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.3450055442610606
# Test loss on 300 iteration:  0.3946926160656157
# Accuracy on 300 iteration:  0.8433734939759037
# Recall on 300 iteration:  0.8444444444444444
# Fscore on 300 iteration:  0.853932584269663
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.30745231249838406
# Test loss on 400 iteration:  0.3900933278828895
# Accuracy on 400 iteration:  0.8554216867469879
# Recall on 400 iteration:  0.8666666666666667
# Fscore on 400 iteration:  0.8666666666666667
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.17506574302932643
# Test loss:  0.39016171207167455
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8433734939759037
# F_score:  0.8571428571428571
# Recall:  0.8666666666666667
#
# learning 0.01
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.6638807346797109
# Test loss on 0 iteration:  0.6768429113748873
# Accuracy on 0 iteration:  0.5180722891566265
# Recall on 0 iteration:  0.1111111111111111
# Fscore on 0 iteration:  0.19999999999999998
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.13770689156744342
# Test loss on 100 iteration:  0.3731228838047431
# Accuracy on 100 iteration:  0.8313253012048193
# Recall on 100 iteration:  0.8888888888888888
# Fscore on 100 iteration:  0.851063829787234
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.22893793776899996
# Test loss on 200 iteration:  0.4297245645802038
# Accuracy on 200 iteration:  0.8072289156626506
# Recall on 200 iteration:  0.9111111111111111
# Fscore on 200 iteration:  0.8367346938775511
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.027301936605732356
# Test loss on 300 iteration:  0.5301005785675594
# Accuracy on 300 iteration:  0.8313253012048193
# Recall on 300 iteration:  0.8888888888888888
# Fscore on 300 iteration:  0.851063829787234
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.03544597292884887
# Test loss on 400 iteration:  0.6132865838491481
# Accuracy on 400 iteration:  0.8433734939759037
# Recall on 400 iteration:  0.9111111111111111
# Fscore on 400 iteration:  0.8631578947368421
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.006797601762139507
# Test loss:  0.661450216126443
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8433734939759037
# F_score:  0.8631578947368421
# Recall:  0.9111111111111111
#
# std_dev 0.8
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.5607390268220465
# Test loss on 0 iteration:  1.2819304564467817
# Accuracy on 0 iteration:  0.5421686746987951
# Recall on 0 iteration:  1.0
# Fscore on 0 iteration:  0.7031249999999999
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.47512291905477944
# Test loss on 100 iteration:  0.467099653604747
# Accuracy on 100 iteration:  0.7831325301204819
# Recall on 100 iteration:  0.8
# Fscore on 100 iteration:  0.8000000000000002
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.49968526984621514
# Test loss on 200 iteration:  0.40716496311325745
# Accuracy on 200 iteration:  0.8192771084337349
# Recall on 200 iteration:  0.8444444444444444
# Fscore on 200 iteration:  0.8351648351648352
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.34513742551471976
# Test loss on 300 iteration:  0.3811027523954139
# Accuracy on 300 iteration:  0.8313253012048193
# Recall on 300 iteration:  0.8444444444444444
# Fscore on 300 iteration:  0.8444444444444444
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.20436567607070735
# Test loss on 400 iteration:  0.3723746641097448
# Accuracy on 400 iteration:  0.8554216867469879
# Recall on 400 iteration:  0.8444444444444444
# Fscore on 400 iteration:  0.8636363636363636
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.20188485473120685
# Test loss:  0.3720391870809227
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8674698795180723
# F_score:  0.8764044943820225
# Recall:  0.8666666666666667
#
# std_dev 0.3
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.721791059694823
# Test loss on 0 iteration:  0.6849437666043128
# Accuracy on 0 iteration:  0.5421686746987951
# Recall on 0 iteration:  1.0
# Fscore on 0 iteration:  0.7031249999999999
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.5768280306234579
# Test loss on 100 iteration:  0.5616778790122905
# Accuracy on 100 iteration:  0.8433734939759037
# Recall on 100 iteration:  0.8222222222222222
# Fscore on 100 iteration:  0.8505747126436781
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.5379341860670596
# Test loss on 200 iteration:  0.4216308651731066
# Accuracy on 200 iteration:  0.8433734939759037
# Recall on 200 iteration:  0.8444444444444444
# Fscore on 200 iteration:  0.853932584269663
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.3338362067274224
# Test loss on 300 iteration:  0.3839603108965372
# Accuracy on 300 iteration:  0.8433734939759037
# Recall on 300 iteration:  0.8666666666666667
# Fscore on 300 iteration:  0.8571428571428571
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.26175680171996907
# Test loss on 400 iteration:  0.3761273649960635
# Accuracy on 400 iteration:  0.8433734939759037
# Recall on 400 iteration:  0.8666666666666667
# Fscore on 400 iteration:  0.8571428571428571
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.11970374934086646
# Test loss:  0.37449856032545314
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8433734939759037
# F_score:  0.8571428571428571
# Recall:  0.8666666666666667
#
# layer size (20,)
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  1.6182148990706269
# Test loss on 0 iteration:  0.9552740948909214
# Accuracy on 0 iteration:  0.5421686746987951
# Recall on 0 iteration:  1.0
# Fscore on 0 iteration:  0.7031249999999999
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.21247923639284483
# Test loss on 100 iteration:  0.4073652874213974
# Accuracy on 100 iteration:  0.7951807228915663
# Recall on 100 iteration:  0.8444444444444444
# Fscore on 100 iteration:  0.8172043010752689
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.22142771020563845
# Test loss on 200 iteration:  0.3849464834402949
# Accuracy on 200 iteration:  0.8072289156626506
# Recall on 200 iteration:  0.8666666666666667
# Fscore on 200 iteration:  0.8297872340425533
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.41507157402522543
# Test loss on 300 iteration:  0.38404209900898956
# Accuracy on 300 iteration:  0.8313253012048193
# Recall on 300 iteration:  0.8888888888888888
# Fscore on 300 iteration:  0.851063829787234
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.1535233662827746
# Test loss on 400 iteration:  0.38599004753316957
# Accuracy on 400 iteration:  0.8313253012048193
# Recall on 400 iteration:  0.8888888888888888
# Fscore on 400 iteration:  0.851063829787234
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.21742223308275505
# Test loss:  0.3888153041081694
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8192771084337349
# F_score:  0.8421052631578948
# Recall:  0.8888888888888888
#
# layer size (20, 20)
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.9190735544835285
# Test loss on 0 iteration:  0.7215625253881373
# Accuracy on 0 iteration:  0.5421686746987951
# Recall on 0 iteration:  1.0
# Fscore on 0 iteration:  0.7031249999999999
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.5262944081847174
# Test loss on 100 iteration:  0.5642844488929157
# Accuracy on 100 iteration:  0.7831325301204819
# Recall on 100 iteration:  0.7777777777777778
# Fscore on 100 iteration:  0.7954545454545455
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.39028377980941203
# Test loss on 200 iteration:  0.420901867160615
# Accuracy on 200 iteration:  0.8433734939759037
# Recall on 200 iteration:  0.8222222222222222
# Fscore on 200 iteration:  0.8505747126436781
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.14504337137186465
# Test loss on 300 iteration:  0.39366499578610187
# Accuracy on 300 iteration:  0.8433734939759037
# Recall on 300 iteration:  0.8444444444444444
# Fscore on 300 iteration:  0.853932584269663
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.41438440145185457
# Test loss on 400 iteration:  0.388780344739313
# Accuracy on 400 iteration:  0.8674698795180723
# Recall on 400 iteration:  0.8666666666666667
# Fscore on 400 iteration:  0.8764044943820225
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.27101172624378456
# Test loss:  0.3880756249952635
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8554216867469879
# F_score:  0.8666666666666667
# Recall:  0.8666666666666667
#
# layer size (20, 20, 20)
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.6809286544454091
# Test loss on 0 iteration:  0.6799568114642314
# Accuracy on 0 iteration:  0.5421686746987951
# Recall on 0 iteration:  1.0
# Fscore on 0 iteration:  0.7031249999999999
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.6490115975112892
# Test loss on 100 iteration:  0.6572864674997282
# Accuracy on 100 iteration:  0.7228915662650602
# Recall on 100 iteration:  0.5111111111111111
# Fscore on 100 iteration:  0.6666666666666666
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.4815547591092954
# Test loss on 200 iteration:  0.5447239370631797
# Accuracy on 200 iteration:  0.8554216867469879
# Recall on 200 iteration:  0.8222222222222222
# Fscore on 200 iteration:  0.8604651162790697
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.32103645793277047
# Test loss on 300 iteration:  0.3997763864612117
# Accuracy on 300 iteration:  0.8433734939759037
# Recall on 300 iteration:  0.8444444444444444
# Fscore on 300 iteration:  0.853932584269663
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.31533533805145053
# Test loss on 400 iteration:  0.3751019775390331
# Accuracy on 400 iteration:  0.8192771084337349
# Recall on 400 iteration:  0.8666666666666667
# Fscore on 400 iteration:  0.8387096774193549
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.3870439067571421
# Test loss:  0.37564826945235896
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8433734939759037
# F_score:  0.8602150537634408
# Recall:  0.8888888888888888

# %%
features_n_std = n_std_result.loc[:, result_df.columns != "heart_disease"].to_numpy()
targets_n_std = n_std_result["heart_disease"].to_numpy()

x_train_n_std, y_train_n_std, x_test_n_std, y_test_n_std = train_test_split(features_n_std, targets_n_std, 70)

model_std = MultilayerNetwork(hidden2)
result = model_std.optimize(x_train, y_train, x_test, y_test, 30, 0.001, max_iter, 0.5, verb=True)
models.append(model_std)
results.append(result)

model_n_std = MultilayerNetwork(hidden2)
result = model_n_std.optimize(x_train_n_std, y_train_n_std, x_test_n_std, y_test_n_std, 30, 0.001, max_iter, 0.5, verb=True)
models.append(model_n_std)
results.append(result)
# Out:
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.7169290434839415
# Test loss on 0 iteration:  0.7285900426933418
# Accuracy on 0 iteration:  0.4457831325301205
# Recall on 0 iteration:  0.022222222222222223
# Fscore on 0 iteration:  0.04166666666666667
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.5479483570867855
# Test loss on 100 iteration:  0.5942415035491571
# Accuracy on 100 iteration:  0.7831325301204819
# Recall on 100 iteration:  0.7777777777777778
# Fscore on 100 iteration:  0.7954545454545455
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.29330714915706335
# Test loss on 200 iteration:  0.4480946218231618
# Accuracy on 200 iteration:  0.8433734939759037
# Recall on 200 iteration:  0.8444444444444444
# Fscore on 200 iteration:  0.853932584269663
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.428988732255708
# Test loss on 300 iteration:  0.4047783883651865
# Accuracy on 300 iteration:  0.8674698795180723
# Recall on 300 iteration:  0.8666666666666667
# Fscore on 300 iteration:  0.8764044943820225
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.3843681161606769
# Test loss on 400 iteration:  0.388920130736936
# Accuracy on 400 iteration:  0.8674698795180723
# Recall on 400 iteration:  0.8666666666666667
# Fscore on 400 iteration:  0.8764044943820225
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.44688467466121545
# Test loss:  0.3808281705757098
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8674698795180723
# F_score:  0.8764044943820225
# Recall:  0.8666666666666667
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  1.2430571640950323
# Test loss on 0 iteration:  0.9912206849360122
# Accuracy on 0 iteration:  0.5060240963855421
# Recall on 0 iteration:  1.0
# Fscore on 0 iteration:  0.6719999999999999
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.6682017037603417
# Test loss on 100 iteration:  0.6799783349065999
# Accuracy on 100 iteration:  0.6506024096385542
# Recall on 100 iteration:  0.7380952380952381
# Fscore on 100 iteration:  0.6813186813186813
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.7151577100794458
# Test loss on 200 iteration:  0.6836526890199724
# Accuracy on 200 iteration:  0.5662650602409639
# Recall on 200 iteration:  0.8809523809523809
# Fscore on 200 iteration:  0.6727272727272727
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.682715803864125
# Test loss on 300 iteration:  0.6281348445118999
# Accuracy on 300 iteration:  0.6987951807228916
# Recall on 300 iteration:  0.6904761904761905
# Fscore on 300 iteration:  0.6987951807228916
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.6912613508427458
# Test loss on 400 iteration:  0.6192933198392844
# Accuracy on 400 iteration:  0.6867469879518072
# Recall on 400 iteration:  0.7380952380952381
# Fscore on 400 iteration:  0.7045454545454546
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.4954718419742281
# Test loss:  0.6428267389604254
# ----------------------------------------------
#
# Scores
# Accuracy:  0.6385542168674698
# F_score:  0.7115384615384616
# Recall:  0.8809523809523809

# %%
plt.style.use('seaborn-muted')
fig, axs = plt.subplots(6, 2, figsize=(20, 25))

for model_index, model in enumerate(models):
    x_index = int(model_index / 2)
    y_index = int(model_index % 2)
    model.plot_learning(results[model_index][0], results[model_index][1], options_title[model_index], axs[x_index, y_index])
# Out:
# /var/folders/mh/bbwr87kx54j1nws7g0r4tlg80000gn/T/ipykernel_83575/3425124311.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-muted')
