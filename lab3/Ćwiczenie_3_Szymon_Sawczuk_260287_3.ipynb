# %% [markdown]
# <h1>Sieci neuronowe - ćwiczenie 3</h1>

# %%
# !pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in /Users/szymon/.pyenv/versions/3.10.6/lib/python3.10/site-packages (0.0.2)
#
# [notice] A new release of pip available: 22.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.metrics as metrics

# %% [markdown]
# <h3>Przygotowanie danych na podstawie poprzedniego ćwiczenia</h3>

# %%
# original code from https://archive.ics.uci.edu/dataset/45/heart+disease
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 
  
# data (as pandas dataframes) 
heart_data = heart_disease.data.original

# %%
df: pd.DataFrame = heart_data

# repearing of the inbalnace in classification and removing null values
df["num"] = df["num"].replace([2, 3, 4], 1) #change classes to binary classification
print(df["num"].value_counts())

#get null values of ca and remove them
null_idx = df[df["ca"].isnull()].index 
print(null_idx)
df = df.drop(null_idx)
df = df.reset_index(drop=True) 
print(df["num"].value_counts())

#get null values of thel and remove them
null_idx = df[df["thal"].isnull()].index 
print(null_idx)
df = df.drop(null_idx)
df = df.reset_index(drop=True) 
print(df["num"].value_counts())

# balance classes to same amount 138
random_idx = df.query("num == 0").sample(df["num"].value_counts()[0] - df["num"].value_counts()[1]).index 
df = df.drop(random_idx)
df = df.reset_index(drop=True)
print(df["num"].value_counts())

df_without_num = df.loc[:, df.columns != "num"]
std_features = (df_without_num - df_without_num.mean() )/ df_without_num.std() #(value-mean)/variance

result_df = std_features
result_df["heart_disease"] = df["num"]

# data not standarized 4. Danych znormalizowanych i nieznormalizowanych
n_std_result = df_without_num
n_std_result["heart_disease"] = df["num"]

result_df
# Out:
# num
# 0    164
# 1    139
# Name: count, dtype: int64
# Index([166, 192, 287, 302], dtype='int64')
# num
# 0    161
# 1    138
# Name: count, dtype: int64
# Index([87, 264], dtype='int64')
# num
# 0    160
# 1    137
# Name: count, dtype: int64
# num
# 0    137
# 1    137
# Name: count, dtype: int64
#           age       sex        cp  trestbps      chol       fbs   restecg  \
# 0    0.905857  0.663696 -2.280658  0.727700 -0.301841  2.345986  0.998227
# 1    1.356524  0.663696  0.833463  1.561501  0.707911 -0.424704  0.998227
# 2    1.356524  0.663696  0.833463 -0.661969 -0.378049 -0.424704  0.998227
# 3   -2.023479  0.663696 -0.204577 -0.106102  0.022042 -0.424704 -1.012907
# 4   -1.572812 -1.501216 -1.242618 -0.106102 -0.854347 -0.424704  0.998227
# ..        ...       ...       ...       ...       ...       ...       ...
# 269  0.229857 -1.501216  0.833463  0.449766 -0.149425 -0.424704 -1.012907
# 270 -1.122145  0.663696 -2.280658 -1.217837  0.288769 -0.424704 -1.012907
# 271  1.469191  0.663696  0.833463  0.672113 -1.063918  2.345986 -1.012907
# 272  0.229857  0.663696  0.833463 -0.106102 -2.245137 -0.424704 -1.012907
# 273  0.229857 -1.501216 -1.242618 -0.106102 -0.244685 -0.424704  0.998227
#
#       thalach     exang   oldpeak     slope        ca      thal  heart_disease
# 0    0.040034 -0.727179  1.011179  2.232886 -0.749379  0.607927              0
# 1   -1.766686  1.370158  0.337265  0.618609  2.409541 -0.934407              1
# 2   -0.863326  1.370158  1.263897  0.618609  1.356568  1.122039              1
# 3    1.631669 -0.727179  2.022050  2.232886 -0.749379 -0.934407              0
# 4    0.986411 -0.727179  0.253025 -0.995667 -0.749379 -0.934407              0
# ..        ...       ...       ...       ...       ...       ...            ...
# 269 -1.121429  1.370158 -0.757846  0.618609 -0.749379  1.122039              1
# 270 -0.734274 -0.727179  0.084547  0.618609 -0.749379  1.122039              1
# 271 -0.347120 -0.727179  1.937811  0.618609  1.356568  1.122039              1
# 272 -1.465566  1.370158  0.084547  0.618609  0.303594  1.122039              1
# 273  1.072446 -0.727179 -0.926325  0.618609  0.303594 -0.934407              1
#
# [274 rows x 14 columns]

# %%
def train_test_split(features, targets, percentage):
    choices = np.random.choice(range(features.shape[0]), size=(int(features.shape[0] * percentage/100),), replace=False) 
    split = np.zeros(features.shape[0], dtype=bool)
    split[choices] = True

    return features[split], targets[split], features[~split], targets[~split]

# %%
features = result_df.loc[:, result_df.columns != "heart_disease"].to_numpy()
targets = result_df["heart_disease"].to_numpy()

x_train, y_train, x_test, y_test = train_test_split(features, targets, 70)

# %% [markdown]
# <h1>Przygotowanie modelu</h1>

# %%
def sigmoid(n):
    return 1 / (1 + np.exp(-n))


def sigmoid_der(n):
    return sigmoid(n) * (1 - sigmoid(n))

# %%
class Neuron:
    weights: np.ndarray
    bias: float
    _err: np.ndarray 

    def init_params(self, std_dev: float, weights_size: float):
        self.weights = np.random.normal(scale=std_dev, size=weights_size) # initialize weights 
        self.bias = np.random.normal(scale=std_dev) #initialize bias 

    def forward(self, x: np.ndarray) -> np.ndarray: 
        return sigmoid(np.dot(x, self.weights) + self.bias)
        
    def backward(self, x: np.ndarray, err: np.ndarray, is_output: bool, curr_weights: np.ndarray = np.array([])) -> np.ndarray:
        if not is_output:
            err = err.T @ curr_weights
        self._err = err * sigmoid_der(np.dot(x, self.weights) + self.bias)
        return self._err

    def update(self, learning_rate: float, x: np.ndarray) -> None:
        self.weights = self.weights - learning_rate * np.dot(x.T, self._err)
        self.bias = self.bias - learning_rate * np.sum(self._err)

class Layer:
    _cache_x: np.ndarray
    neurons: list[Neuron]

    def __init__(self, neurons_amount: int):
        self.neurons = []
        for _ in range(neurons_amount):
            self.neurons.append(Neuron())

    def init_params(self, std_dev: float, weights_size: float) -> None:
        for neuron in self.neurons:
            neuron.init_params(std_dev, weights_size)

    def forward(self, x: np.ndarray) -> np.ndarray:
        self._cache_x = x
        return np.array([neuron.forward(x) for neuron in self.neurons]).T
    
    def backward(self, err: np.ndarray, is_output: bool, curr_weights: np.ndarray = np.array([])) -> np.ndarray:
        return np.array([neuron.backward(self._cache_x, err, is_output, curr_weights[neuron_index] if not is_output else None) for neuron_index, neuron in enumerate(self.neurons)])

    def get_weights(self) -> np.ndarray:
        return np.array([neuron.weights for neuron in self.neurons]).T
    
    def update(self, learning_rate: float):
        for neuron in self.neurons:
            neuron.update(learning_rate, self._cache_x)

class MultilayerNetwork:
    _layers : list[Layer]
    _batch_size: int

    def __init__(self, hidden_layers_sizes: tuple):
        self._layers = []
        for layer_size in hidden_layers_sizes:
            self._layers.append(Layer(layer_size))

        # output layer
        self._layers.append(Layer(1))

    def __cross_entropy_loss(self, y, y_pred):
        return np.sum(-y * np.log(y_pred) - (1 - y) * np.log(1 - y_pred), axis=1)

    def __cross_entropy_loss_der(self, y, y_pred):
        return np.sum((1 - y) / (1 - y_pred) - y / y_pred, axis=1)

    def forward(self, x: np.ndarray) -> np.ndarray:
        for layer in self._layers:
            x = layer.forward(x)
        return x   
    
    def backward(self, y_train: np.ndarray, y_pred: np.ndarray):
        err = self._layers[-1].backward(self.__cross_entropy_loss_der(y_train, y_pred), True) # calculate error on output layer
        curr_weights = self._layers[-1].get_weights()

        for layer in reversed(self._layers[:-1]):
            err = layer.backward(err, False, curr_weights)
            curr_weights = layer.get_weights()

    def predict(self, x: np.ndarray) -> np.ndarray:
        y_pred = self.forward(x)

        y_pred[y_pred >= 0.5] = 1
        y_pred[y_pred < 0.5] = 0

        return y_pred

    def optimize(self, x_train: np.ndarray, y_train: np.ndarray, x_test: np.ndarray, y_test: np.ndarray, batch_size: int, learning_rate: float, 
                        max_iter: int, std_dev: float, verb = False) -> (list, list, list, list, list):
        self._batch_size = batch_size
        
        # init helper lists
        losses = [] 
        losses_test = []

        accuracy = []
        precision = []
        f_score = []
        recalls = []

        # init weights and biases
        curr_size = x_train.shape[1]

        for layer in self._layers:
            layer.init_params(std_dev, curr_size)
            curr_size = len(layer.neurons)

        #fix shape of y data to match further calculations
        if len(y_test.shape) == 1:
            y_test = y_test[np.newaxis].T 

        if len(y_train.shape) == 1:
            y_train = y_train[np.newaxis].T

        # check if batch_size is not larger than size of training data
        if batch_size > x_train.shape[0]:
            batch_size = x_train.shape[0]

        for index in range(max_iter): #learn for max_iter     
            # shuffle training data
            shuffle = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[shuffle]
            y_train_shuffled = y_train[shuffle]
            
            # for each batch perform learning
            for batch_start_index in range(0, x_train.shape[0], batch_size):
                x_train_batch = x_train_shuffled[batch_start_index:batch_start_index+batch_size] 
                y_train_batch = y_train_shuffled[batch_start_index:batch_start_index+batch_size] 

                y_pred = self.forward(x_train_batch)
                self.backward(y_train_batch, y_pred)
                
                for layer in self._layers:
                    layer.update(learning_rate)

                new_train_batch_loss = np.array([])
                new_train_batch_loss = np.append(new_train_batch_loss, self.__cross_entropy_loss(y_train_batch, y_pred))

            new_train_loss = np.mean(new_train_batch_loss)

            test_pred = self.forward(x_test)
            new_test_loss = np.mean(self.__cross_entropy_loss(y_test, test_pred))

            #append to helper lists
            losses.append(new_train_loss)
            losses_test.append(new_test_loss)

            # predict test values as 0 or 1
            test_pred = self.predict(x_test)

            #calculate scores for each iteration
            accuracy.append(metrics.accuracy_score(y_test, test_pred))
            precision.append(metrics.precision_score(y_test, test_pred))
            f_score.append(metrics.f1_score(y_test, test_pred))
            recalls.append(metrics.recall_score(y_test, test_pred))

            if verb and index % 100 == 0: 
                print("---------------------------------------------- Interation " + str(index))
                print("Train loss on " + str(index) + " iteration: ", losses[index])
                print("Test loss on " + str(index) + " iteration: ", losses_test[index])
                print("Accuracy on " + str(index) + " iteration: ", accuracy[index])
                print("Precision on " + str(index) + " iteration: ", precision[index])
                print("Recall on " + str(index) + " iteration: ", recalls[index])
                print("Fscore on " + str(index) + " iteration: ", f_score[index])
                print("----------------------------------------------\n")

        print("Result of learning process for " + str(max_iter) + " iterations")
        print("--------------------------------------------------------\n")
        print("Train loss: ", losses[-1])
        print("Test loss: ", losses_test[-1])
        print("----------------------------------------------\n")
        print("Scores")
        print("Accuracy: ", accuracy[-1])
        print("Precision: ", precision[-1])
        print("F_score: ", f_score[-1])
        print("Recall: ", recalls[-1])
        return losses, losses_test, accuracy, f_score, recalls  

    def plot_learning(self, losses: list, losses_test: list, title: str, axs = None):
        if axs == None:
            plt.plot(np.arange(len(losses)), losses, label="Train Loss")
            plt.plot(np.arange(len(losses)), losses_test, label="Test loss")
            plt.plot(np.convolve(losses, np.ones(self._batch_size)/self._batch_size, mode='valid'), label="Train loss smooth") #rolling avarage to smooth line
            plt.title(title)
            plt.legend()
            plt.show()
        else:
            axs.plot(np.arange(len(losses)), losses, label="Train Loss")
            axs.plot(np.arange(len(losses)), losses_test, label="Test loss")
            axs.plot(np.convolve(losses, np.ones(self._batch_size)/self._batch_size, mode='valid'), label="Train loss smooth") #rolling avarage to smooth line
            axs.set_title(title)
            axs.legend()

# %%
#1. Różna wymiarowość warstwy ukrytej
hidden1 = (4, 3)
hidden2 = (20, 10)
hidden3 = (100, 50)

#2. Różne wartości współczynnika uczenia
learning1 = 0.001
learning2 = 0.01

#3. Różne odchylenia standardowych przy inicjalizacji wag
std_dev1 = 0.8
std_dev2 = 0.3

#5. Różne liczby warstw
hidden4 = (20,)
hidden5 = (20, 20)
hidden6 = (20, 20, 20)

max_iter = 500

options_title = ["hidden_layer " + str(hidden1), "hidden_layer " + str(hidden2), "hidden_layer " + str(hidden3),
           "learning " + str(learning1), "learning " + str(learning2),
           "std_dev " + str(std_dev1), "std_dev " + str(std_dev2),
           "layer size " + str(hidden4), "layer size " + str(hidden5), "layer size " + str(hidden6),
           "stadarized data", "not standarized data"]

options = [[hidden1, learning1, std_dev2], [hidden2, learning1, std_dev2], [hidden3, learning1, std_dev2],
           [hidden2, learning1, std_dev2], [hidden2, learning2, std_dev2],
           [hidden2, learning1, std_dev1], [hidden2, learning1, std_dev2],
           [hidden4, learning1, std_dev2], [hidden5, learning1, std_dev2], [hidden6, learning1, std_dev2]]

# %%
import warnings
warnings.filterwarnings('ignore') #hide warning for precision (first iterations have no precision and python gives a warning, to clear output hide it)

# %%
hidden_layers = [hidden1, hidden2, hidden3]
results = []
models = []
for index_option, option in enumerate(options):
    print("\n" + options_title[index_option])
    model = MultilayerNetwork(option[0])
    result = model.optimize(x_train, y_train, x_test, y_test, 30, option[1], max_iter, option[2], verb=True)
    models.append(model)
    results.append(result)
# Out:
# hidden_layer (4, 3)
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.7308941105701042
# Test loss on 0 iteration:  0.6926098877482408
# Accuracy on 0 iteration:  0.5060240963855421
# Precision on 0 iteration:  0.0
# Recall on 0 iteration:  0.0
# Fscore on 0 iteration:  0.0
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.6853618295301895
# Test loss on 100 iteration:  0.6884192804816996
# Accuracy on 100 iteration:  0.6626506024096386
# Precision on 100 iteration:  0.6101694915254238
# Recall on 100 iteration:  0.8780487804878049
# Fscore on 100 iteration:  0.7200000000000001
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.6849430189512299
# Test loss on 200 iteration:  0.6766554318481862
# Accuracy on 200 iteration:  0.7590361445783133
# Precision on 200 iteration:  0.723404255319149
# Recall on 200 iteration:  0.8292682926829268
# Fscore on 200 iteration:  0.7727272727272727
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.6082342993148979
# Test loss on 300 iteration:  0.6329480819633144
# Accuracy on 300 iteration:  0.7831325301204819
# Precision on 300 iteration:  0.7804878048780488
# Recall on 300 iteration:  0.7804878048780488
# Fscore on 300 iteration:  0.7804878048780488
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.43002758889654563
# Test loss on 400 iteration:  0.525303129797449
# Accuracy on 400 iteration:  0.8192771084337349
# Precision on 400 iteration:  0.8421052631578947
# Recall on 400 iteration:  0.7804878048780488
# Fscore on 400 iteration:  0.810126582278481
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.5896955050762742
# Test loss:  0.45425738648712943
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8192771084337349
# Precision:  0.8611111111111112
# F_score:  0.8051948051948052
# Recall:  0.7560975609756098
#
# hidden_layer (20, 10)
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.756373884422391
# Test loss on 0 iteration:  0.70975570112608
# Accuracy on 0 iteration:  0.4939759036144578
# Precision on 0 iteration:  0.4939759036144578
# Recall on 0 iteration:  1.0
# Fscore on 0 iteration:  0.6612903225806451
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.6163592375111935
# Test loss on 100 iteration:  0.6163035611413085
# Accuracy on 100 iteration:  0.7590361445783133
# Precision on 100 iteration:  0.7837837837837838
# Recall on 100 iteration:  0.7073170731707317
# Fscore on 100 iteration:  0.7435897435897435
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.5798001250036942
# Test loss on 200 iteration:  0.46687621578858524
# Accuracy on 200 iteration:  0.8072289156626506
# Precision on 200 iteration:  0.8571428571428571
# Recall on 200 iteration:  0.7317073170731707
# Fscore on 200 iteration:  0.7894736842105263
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.32207101574511443
# Test loss on 300 iteration:  0.43668994551604956
# Accuracy on 300 iteration:  0.8192771084337349
# Precision on 300 iteration:  0.8611111111111112
# Recall on 300 iteration:  0.7560975609756098
# Fscore on 300 iteration:  0.8051948051948052
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.171509065144164
# Test loss on 400 iteration:  0.450521276957534
# Accuracy on 400 iteration:  0.8192771084337349
# Precision on 400 iteration:  0.8611111111111112
# Recall on 400 iteration:  0.7560975609756098
# Fscore on 400 iteration:  0.8051948051948052
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.526541931532727
# Test loss:  0.45853098304659107
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8072289156626506
# Precision:  0.8571428571428571
# F_score:  0.7894736842105263
# Recall:  0.7317073170731707
#
# hidden_layer (100, 50)
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.8196017788005363
# Test loss on 0 iteration:  0.7249855168499958
# Accuracy on 0 iteration:  0.4457831325301205
# Precision on 0 iteration:  0.4074074074074074
# Recall on 0 iteration:  0.2682926829268293
# Fscore on 0 iteration:  0.3235294117647059
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.4331755232101463
# Test loss on 100 iteration:  0.4279302485391963
# Accuracy on 100 iteration:  0.7831325301204819
# Precision on 100 iteration:  0.8108108108108109
# Recall on 100 iteration:  0.7317073170731707
# Fscore on 100 iteration:  0.7692307692307694
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.4538571464260883
# Test loss on 200 iteration:  0.44164255606637937
# Accuracy on 200 iteration:  0.8192771084337349
# Precision on 200 iteration:  0.8611111111111112
# Recall on 200 iteration:  0.7560975609756098
# Fscore on 200 iteration:  0.8051948051948052
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.5964823014552006
# Test loss on 300 iteration:  0.45274059746758344
# Accuracy on 300 iteration:  0.8192771084337349
# Precision on 300 iteration:  0.8611111111111112
# Recall on 300 iteration:  0.7560975609756098
# Fscore on 300 iteration:  0.8051948051948052
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.2721708384004602
# Test loss on 400 iteration:  0.46241564187599854
# Accuracy on 400 iteration:  0.7951807228915663
# Precision on 400 iteration:  0.8529411764705882
# Recall on 400 iteration:  0.7073170731707317
# Fscore on 400 iteration:  0.7733333333333334
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.2688248203145756
# Test loss:  0.4682035507091314
# ----------------------------------------------
#
# Scores
# Accuracy:  0.7831325301204819
# Precision:  0.8285714285714286
# F_score:  0.7631578947368421
# Recall:  0.7073170731707317
#
# learning 0.001
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.9796828432575656
# Test loss on 0 iteration:  0.7803238959990116
# Accuracy on 0 iteration:  0.5060240963855421
# Precision on 0 iteration:  0.0
# Recall on 0 iteration:  0.0
# Fscore on 0 iteration:  0.0
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.6700335978515418
# Test loss on 100 iteration:  0.6318829856555059
# Accuracy on 100 iteration:  0.7951807228915663
# Precision on 100 iteration:  0.8529411764705882
# Recall on 100 iteration:  0.7073170731707317
# Fscore on 100 iteration:  0.7733333333333334
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.3963992529252639
# Test loss on 200 iteration:  0.46299907130383905
# Accuracy on 200 iteration:  0.7951807228915663
# Precision on 200 iteration:  0.8333333333333334
# Recall on 200 iteration:  0.7317073170731707
# Fscore on 200 iteration:  0.7792207792207793
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.2674392438045832
# Test loss on 300 iteration:  0.4299979741404818
# Accuracy on 300 iteration:  0.8072289156626506
# Precision on 300 iteration:  0.8571428571428571
# Recall on 300 iteration:  0.7317073170731707
# Fscore on 300 iteration:  0.7894736842105263
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.32699268369030443
# Test loss on 400 iteration:  0.44884357371394434
# Accuracy on 400 iteration:  0.8072289156626506
# Precision on 400 iteration:  0.8378378378378378
# Recall on 400 iteration:  0.7560975609756098
# Fscore on 400 iteration:  0.7948717948717948
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.2268588529423354
# Test loss:  0.46221575321885955
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8192771084337349
# Precision:  0.8611111111111112
# F_score:  0.8051948051948052
# Recall:  0.7560975609756098
#
# learning 0.01
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.6927081074941605
# Test loss on 0 iteration:  0.6902292729875581
# Accuracy on 0 iteration:  0.5662650602409639
# Precision on 0 iteration:  0.5510204081632653
# Recall on 0 iteration:  0.6585365853658537
# Fscore on 0 iteration:  0.6
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.25773410605022234
# Test loss on 100 iteration:  0.4696705960117185
# Accuracy on 100 iteration:  0.7951807228915663
# Precision on 100 iteration:  0.8333333333333334
# Recall on 100 iteration:  0.7317073170731707
# Fscore on 100 iteration:  0.7792207792207793
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.05950786562627402
# Test loss on 200 iteration:  0.5265652622030791
# Accuracy on 200 iteration:  0.8072289156626506
# Precision on 200 iteration:  0.8378378378378378
# Recall on 200 iteration:  0.7560975609756098
# Fscore on 200 iteration:  0.7948717948717948
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.05065737553962128
# Test loss on 300 iteration:  0.5963529609404378
# Accuracy on 300 iteration:  0.8313253012048193
# Precision on 300 iteration:  0.8461538461538461
# Recall on 300 iteration:  0.8048780487804879
# Fscore on 300 iteration:  0.8250000000000001
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.0060784668354450285
# Test loss on 400 iteration:  0.7812401657303496
# Accuracy on 400 iteration:  0.8192771084337349
# Precision on 400 iteration:  0.825
# Recall on 400 iteration:  0.8048780487804879
# Fscore on 400 iteration:  0.8148148148148149
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.02353243127992571
# Test loss:  0.9124482095925565
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8313253012048193
# Precision:  0.8292682926829268
# F_score:  0.8292682926829268
# Recall:  0.8292682926829268
#
# std_dev 0.8
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.7118072753921613
# Test loss on 0 iteration:  0.7229299608878529
# Accuracy on 0 iteration:  0.4939759036144578
# Precision on 0 iteration:  0.3333333333333333
# Recall on 0 iteration:  0.024390243902439025
# Fscore on 0 iteration:  0.04545454545454545
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.5888002127521385
# Test loss on 100 iteration:  0.5246509124613721
# Accuracy on 100 iteration:  0.7469879518072289
# Precision on 100 iteration:  0.75
# Recall on 100 iteration:  0.7317073170731707
# Fscore on 100 iteration:  0.7407407407407408
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.1671275010309822
# Test loss on 200 iteration:  0.4984830438203232
# Accuracy on 200 iteration:  0.7710843373493976
# Precision on 200 iteration:  0.7894736842105263
# Recall on 200 iteration:  0.7317073170731707
# Fscore on 200 iteration:  0.7594936708860759
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.3169134198294803
# Test loss on 300 iteration:  0.49811370842408986
# Accuracy on 300 iteration:  0.7831325301204819
# Precision on 300 iteration:  0.8108108108108109
# Recall on 300 iteration:  0.7317073170731707
# Fscore on 300 iteration:  0.7692307692307694
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.16614878364851673
# Test loss on 400 iteration:  0.4988420318886096
# Accuracy on 400 iteration:  0.7710843373493976
# Precision on 400 iteration:  0.8055555555555556
# Recall on 400 iteration:  0.7073170731707317
# Fscore on 400 iteration:  0.7532467532467532
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.16109638643647603
# Test loss:  0.500003516506466
# ----------------------------------------------
#
# Scores
# Accuracy:  0.7710843373493976
# Precision:  0.8055555555555556
# F_score:  0.7532467532467532
# Recall:  0.7073170731707317
#
# std_dev 0.3
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.7044147576198081
# Test loss on 0 iteration:  0.7340406162040972
# Accuracy on 0 iteration:  0.4939759036144578
# Precision on 0 iteration:  0.4939759036144578
# Recall on 0 iteration:  1.0
# Fscore on 0 iteration:  0.6612903225806451
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.6415058472994435
# Test loss on 100 iteration:  0.6436983941656025
# Accuracy on 100 iteration:  0.7590361445783133
# Precision on 100 iteration:  0.7837837837837838
# Recall on 100 iteration:  0.7073170731707317
# Fscore on 100 iteration:  0.7435897435897435
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.5435551170574201
# Test loss on 200 iteration:  0.4998714202334592
# Accuracy on 200 iteration:  0.8554216867469879
# Precision on 200 iteration:  0.9142857142857143
# Recall on 200 iteration:  0.7804878048780488
# Fscore on 200 iteration:  0.8421052631578947
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.3943775830338341
# Test loss on 300 iteration:  0.41796036827560135
# Accuracy on 300 iteration:  0.8192771084337349
# Precision on 300 iteration:  0.8611111111111112
# Recall on 300 iteration:  0.7560975609756098
# Fscore on 300 iteration:  0.8051948051948052
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.1983469440351081
# Test loss on 400 iteration:  0.42766938597210524
# Accuracy on 400 iteration:  0.8192771084337349
# Precision on 400 iteration:  0.8611111111111112
# Recall on 400 iteration:  0.7560975609756098
# Fscore on 400 iteration:  0.8051948051948052
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.30496142506773527
# Test loss:  0.4478051662543835
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8192771084337349
# Precision:  0.8611111111111112
# F_score:  0.8051948051948052
# Recall:  0.7560975609756098
#
# layer size (20,)
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.7278608562792549
# Test loss on 0 iteration:  0.7570294940439777
# Accuracy on 0 iteration:  0.5060240963855421
# Precision on 0 iteration:  0.0
# Recall on 0 iteration:  0.0
# Fscore on 0 iteration:  0.0
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.2664181427383964
# Test loss on 100 iteration:  0.43268116800476675
# Accuracy on 100 iteration:  0.7951807228915663
# Precision on 100 iteration:  0.8333333333333334
# Recall on 100 iteration:  0.7317073170731707
# Fscore on 100 iteration:  0.7792207792207793
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.3711218121552615
# Test loss on 200 iteration:  0.4370010119646508
# Accuracy on 200 iteration:  0.7831325301204819
# Precision on 200 iteration:  0.8285714285714286
# Recall on 200 iteration:  0.7073170731707317
# Fscore on 200 iteration:  0.7631578947368421
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.32319865422900435
# Test loss on 300 iteration:  0.44932237635303224
# Accuracy on 300 iteration:  0.7951807228915663
# Precision on 300 iteration:  0.8529411764705882
# Recall on 300 iteration:  0.7073170731707317
# Fscore on 300 iteration:  0.7733333333333334
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.1016738939102186
# Test loss on 400 iteration:  0.45702767170828057
# Accuracy on 400 iteration:  0.7951807228915663
# Precision on 400 iteration:  0.8529411764705882
# Recall on 400 iteration:  0.7073170731707317
# Fscore on 400 iteration:  0.7733333333333334
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.22183069739695604
# Test loss:  0.4618477418972277
# ----------------------------------------------
#
# Scores
# Accuracy:  0.7951807228915663
# Precision:  0.8529411764705882
# F_score:  0.7733333333333334
# Recall:  0.7073170731707317
#
# layer size (20, 20)
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.7125978550003792
# Test loss on 0 iteration:  0.7113548707136509
# Accuracy on 0 iteration:  0.37349397590361444
# Precision on 0 iteration:  0.4246575342465753
# Recall on 0 iteration:  0.7560975609756098
# Fscore on 0 iteration:  0.543859649122807
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.596211474793565
# Test loss on 100 iteration:  0.6182860517329436
# Accuracy on 100 iteration:  0.7590361445783133
# Precision on 100 iteration:  0.8
# Recall on 100 iteration:  0.6829268292682927
# Fscore on 100 iteration:  0.736842105263158
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.5019132281001023
# Test loss on 200 iteration:  0.4623839469274153
# Accuracy on 200 iteration:  0.7951807228915663
# Precision on 200 iteration:  0.8333333333333334
# Recall on 200 iteration:  0.7317073170731707
# Fscore on 200 iteration:  0.7792207792207793
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.44646313267960896
# Test loss on 300 iteration:  0.44035709684800806
# Accuracy on 300 iteration:  0.8072289156626506
# Precision on 300 iteration:  0.8571428571428571
# Recall on 300 iteration:  0.7317073170731707
# Fscore on 300 iteration:  0.7894736842105263
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.4046691804544956
# Test loss on 400 iteration:  0.4530322401182562
# Accuracy on 400 iteration:  0.7951807228915663
# Precision on 400 iteration:  0.8333333333333334
# Recall on 400 iteration:  0.7317073170731707
# Fscore on 400 iteration:  0.7792207792207793
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.45681141837283545
# Test loss:  0.46217503054024067
# ----------------------------------------------
#
# Scores
# Accuracy:  0.7951807228915663
# Precision:  0.8333333333333334
# F_score:  0.7792207792207793
# Recall:  0.7317073170731707
#
# layer size (20, 20, 20)
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.8528703746758609
# Test loss on 0 iteration:  0.7210624086487094
# Accuracy on 0 iteration:  0.5060240963855421
# Precision on 0 iteration:  0.0
# Recall on 0 iteration:  0.0
# Fscore on 0 iteration:  0.0
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.6646017935685693
# Test loss on 100 iteration:  0.6708984930103411
# Accuracy on 100 iteration:  0.8313253012048193
# Precision on 100 iteration:  0.8648648648648649
# Recall on 100 iteration:  0.7804878048780488
# Fscore on 100 iteration:  0.8205128205128206
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.5876169460186436
# Test loss on 200 iteration:  0.6070364126531698
# Accuracy on 200 iteration:  0.8313253012048193
# Precision on 200 iteration:  0.8461538461538461
# Recall on 200 iteration:  0.8048780487804879
# Fscore on 200 iteration:  0.8250000000000001
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.5571005358479323
# Test loss on 300 iteration:  0.4578221674649759
# Accuracy on 300 iteration:  0.8192771084337349
# Precision on 300 iteration:  0.8611111111111112
# Recall on 300 iteration:  0.7560975609756098
# Fscore on 300 iteration:  0.8051948051948052
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.27155242913707583
# Test loss on 400 iteration:  0.42025338288197606
# Accuracy on 400 iteration:  0.8192771084337349
# Precision on 400 iteration:  0.8611111111111112
# Recall on 400 iteration:  0.7560975609756098
# Fscore on 400 iteration:  0.8051948051948052
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.3359658340988504
# Test loss:  0.44032616579948763
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8192771084337349
# Precision:  0.8611111111111112
# F_score:  0.8051948051948052
# Recall:  0.7560975609756098

# %%
features_n_std = n_std_result.loc[:, result_df.columns != "heart_disease"].to_numpy()
targets_n_std = n_std_result["heart_disease"].to_numpy()

x_train_n_std, y_train_n_std, x_test_n_std, y_test_n_std = train_test_split(features_n_std, targets_n_std, 70)

model_std = MultilayerNetwork(hidden2)
result = model_std.optimize(x_train, y_train, x_test, y_test, 30, 0.001, max_iter, 0.5, verb=True)
models.append(model_std)
results.append(result)

model_n_std = MultilayerNetwork(hidden2)
result = model_n_std.optimize(x_train_n_std, y_train_n_std, x_test_n_std, y_test_n_std, 30, 0.001, max_iter, 0.5, verb=True)
models.append(model_n_std)
results.append(result)
# Out:
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  1.0382950451283455
# Test loss on 0 iteration:  0.716106563135108
# Accuracy on 0 iteration:  0.4939759036144578
# Precision on 0 iteration:  0.4939759036144578
# Recall on 0 iteration:  1.0
# Fscore on 0 iteration:  0.6612903225806451
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.47474449963486626
# Test loss on 100 iteration:  0.4505034385779594
# Accuracy on 100 iteration:  0.8313253012048193
# Precision on 100 iteration:  0.8648648648648649
# Recall on 100 iteration:  0.7804878048780488
# Fscore on 100 iteration:  0.8205128205128206
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.14952142329833296
# Test loss on 200 iteration:  0.4229584644414795
# Accuracy on 200 iteration:  0.8192771084337349
# Precision on 200 iteration:  0.8611111111111112
# Recall on 200 iteration:  0.7560975609756098
# Fscore on 200 iteration:  0.8051948051948052
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.20126456651231453
# Test loss on 300 iteration:  0.436248739113555
# Accuracy on 300 iteration:  0.8313253012048193
# Precision on 300 iteration:  0.8857142857142857
# Recall on 300 iteration:  0.7560975609756098
# Fscore on 300 iteration:  0.8157894736842105
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.9036261446784088
# Test loss on 400 iteration:  0.45019455874513387
# Accuracy on 400 iteration:  0.8072289156626506
# Precision on 400 iteration:  0.8571428571428571
# Recall on 400 iteration:  0.7317073170731707
# Fscore on 400 iteration:  0.7894736842105263
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.12066679477949732
# Test loss:  0.4609948426714169
# ----------------------------------------------
#
# Scores
# Accuracy:  0.8072289156626506
# Precision:  0.8571428571428571
# F_score:  0.7894736842105263
# Recall:  0.7317073170731707
# ---------------------------------------------- Interation 0
# Train loss on 0 iteration:  0.7228195311023583
# Test loss on 0 iteration:  0.6951976523005747
# Accuracy on 0 iteration:  0.5662650602409639
# Precision on 0 iteration:  0.6363636363636364
# Recall on 0 iteration:  0.1794871794871795
# Fscore on 0 iteration:  0.28
# ----------------------------------------------
#
# ---------------------------------------------- Interation 100
# Train loss on 100 iteration:  0.6450189908647176
# Test loss on 100 iteration:  0.6429617539940021
# Accuracy on 100 iteration:  0.6385542168674698
# Precision on 100 iteration:  0.5714285714285714
# Recall on 100 iteration:  0.9230769230769231
# Fscore on 100 iteration:  0.7058823529411765
# ----------------------------------------------
#
# ---------------------------------------------- Interation 200
# Train loss on 200 iteration:  0.6591994058959082
# Test loss on 200 iteration:  0.5645461536968603
# Accuracy on 200 iteration:  0.7590361445783133
# Precision on 200 iteration:  0.7317073170731707
# Recall on 200 iteration:  0.7692307692307693
# Fscore on 200 iteration:  0.7499999999999999
# ----------------------------------------------
#
# ---------------------------------------------- Interation 300
# Train loss on 300 iteration:  0.6218760160914318
# Test loss on 300 iteration:  0.5709784381398395
# Accuracy on 300 iteration:  0.7469879518072289
# Precision on 300 iteration:  0.725
# Recall on 300 iteration:  0.7435897435897436
# Fscore on 300 iteration:  0.7341772151898733
# ----------------------------------------------
#
# ---------------------------------------------- Interation 400
# Train loss on 400 iteration:  0.5997750930401451
# Test loss on 400 iteration:  0.5579009826167067
# Accuracy on 400 iteration:  0.8072289156626506
# Precision on 400 iteration:  0.7555555555555555
# Recall on 400 iteration:  0.8717948717948718
# Fscore on 400 iteration:  0.8095238095238095
# ----------------------------------------------
#
# Result of learning process for 500 iterations
# --------------------------------------------------------
#
# Train loss:  0.5333310035910988
# Test loss:  0.6059169682318617
# ----------------------------------------------
#
# Scores
# Accuracy:  0.7349397590361446
# Precision:  0.7428571428571429
# F_score:  0.7027027027027027
# Recall:  0.6666666666666666

# %%
plt.style.use('seaborn-muted')
fig, axs = plt.subplots(6, 2, figsize=(20, 25))

for model_index, model in enumerate(models):
    x_index = int(model_index / 2)
    y_index = int(model_index % 2)
    model.plot_learning(results[model_index][0], results[model_index][1], options_title[model_index], axs[x_index, y_index])
# Out:
# /var/folders/mh/bbwr87kx54j1nws7g0r4tlg80000gn/T/ipykernel_9630/3425124311.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-muted')
